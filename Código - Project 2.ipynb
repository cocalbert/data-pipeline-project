# %%
#IMPORTAMOS CSV A PYTHON
import pandas as pd

df = pd.read_csv(r'/Users/albertcoca/Desktop/bootcamp/Project_2/HR-Employee-Attrition.csv')

df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#EXPLORAMOS EL DATAFRAME

# %%
df.shape
# Out:
# (1470, 33)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                    int64
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %%
# About Data: No missing data

# %%
#  Attrition rate en el dataset

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # EXPLORACIÓN DE LOS DATOS DEL DATAFRAME

# %%
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
# ...

# %%
sns.histplot(x=df['MonthlyIncome'], kde=True); #subplot

# %% [markdown]
# # ANALISIS DEL ATTRITION

# %%
df.Attrition.value_counts()/len(df)*100
# Out:
# 0    83.877551
# 1    16.122449
# Name: Attrition, dtype: float64

# %%
pal = sns.color_palette("GnBu",n_colors=2)

def count_Plot(feature, data,xl,yl,axs,hu=None):
    ax = sns.countplot(x=feature,palette=pal, data=data,hue=hu,ax=axs)
    for p in ax.patches:
        ax.annotate(f'\n{p.get_height()}',(p.get_x()+0.2,p.get_height()),  ha='center', va='center', size=18)
    axs.set(xlabel=xl, ylabel=yl)
    
#definimos el pieplot
    
def pie_plot(feature,data,xl,axs):
    co = data[feature].value_counts(normalize=True)
    labels = ['Employee Stay','Employee Quit']
    
    axs.pie(co, labels = labels, colors=pal,autopct='%.0f%%')
    axs.set(xlabel=xl)
    

fig, axes = plt.subplots(1,2, figsize=(16, 6))
count_Plot("Attrition",df,"Employee Attrition in number","amount",axes[0])
pie_plot('Attrition',df,"Employee Attrtion in Percentage",axes[1])

# %%
attrition_currentmanager = df.groupby('Attrition')['YearsWithCurrManager'].mean()
attrition_currentmanager
# Out:
# Attrition
# No     4.367397
# Yes    2.852321
# Name: YearsWithCurrManager, dtype: float64

# %%
plt.figure(figsize=(5, 3))
plt.bar(attrition_currentmanager.index, attrition_currentmanager.values)
plt.xlabel('Attrition')
plt.ylabel('Years With Current Manager')
plt.title('Relationship between Attrition and Years With Current Manager')
plt.show()

# %%
attrition_lastpromotion = df.groupby('Attrition')['YearsSinceLastPromotion'].mean()
attrition_lastpromotion
# Out:
# Attrition
# No     2.234388
# Yes    1.945148
# Name: YearsSinceLastPromotion, dtype: float64

# %%
plt.figure(figsize=(6, 4))
plt.bar(attrition_lastpromotion.index, attrition_lastpromotion.values)
plt.xlabel('Attrition')
plt.ylabel('Years Since Last Promotion')
plt.title('Relationship between Attrition and Years Since Last Promotion')
plt.show()

# %%
attrition_DailyRate = df.groupby('Attrition')['DailyRate'].mean()
attrition_DailyRate
# Out:
# Attrition
# No     812.504461
# Yes    750.362869
# Name: DailyRate, dtype: float64

# %%
plt.figure(figsize=(6, 4))
plt.bar(attrition_DailyRate.index, attrition_DailyRate.values)
plt.xlabel('Attrition')
plt.ylabel('attrition_DailyRate')
plt.title('Relationship between Attrition and Daily Rate')
plt.show()

# %%
attrition_YearsInCurrentRole = df.groupby('Attrition')['YearsInCurrentRole'].mean()
attrition_YearsInCurrentRole
# Out:
# Attrition
# No     4.484185
# Yes    2.902954
# Name: YearsInCurrentRole, dtype: float64

# %%
plt.figure(figsize=(6, 4))
plt.bar(attrition_YearsInCurrentRole.index, attrition_YearsInCurrentRole.values)
plt.xlabel('Attrition')
plt.ylabel('YearsInCurrentRole')
plt.title('Relationship between Attrition and YearsInCurrentRole')
plt.show()

# %%
attrition_TrainingTimesLastYear = df.groupby('Attrition')['TrainingTimesLastYear'].mean()
attrition_TrainingTimesLastYear
# Out:
# Attrition
# No     2.832928
# Yes    2.624473
# Name: TrainingTimesLastYear, dtype: float64

# %%
plt.figure(figsize=(6, 4))
plt.bar(attrition_TrainingTimesLastYear.index, attrition_TrainingTimesLastYear.values)
plt.xlabel('Attrition')
plt.ylabel('TrainingTimesLastYear')
plt.title('Relationship between Attrition and Training Times Last Year')
plt.show()

# %%
attrition_Age = df.groupby('Attrition')[['Age']].mean()
attrition_Age
# Out:
#                  Age
# Attrition
# No         37.561233
# Yes        33.607595

# %%
se_van = df[df["Attrition"]==True]
se_quedan = df[df["Attrition"]==False]

# %%
import pandas as pd
from scipy.stats import ttest_ind

# %%
t_stat, p_val = ttest_ind(se_van['Attrition'], se_quedan['Attrition'])

# %%
p_val
# Out:
# 0.0

# %%
attrition_currentmanager = df.groupby('Attrition')['YearsWithCurrManager'].mean()
attrition_currentmanager
# Out:
# Attrition
# No     4.367397
# Yes    2.852321
# Name: YearsWithCurrManager, dtype: float64

# %%
f,ax = plt.subplots(figsize=(20, 20))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %%
df_test = df['TrainingTimesLastYear']
print(df_test)
# Out:
# 0       0
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1465    3
# 1466    5
# 1467    0
# 1468    3
# 1469    3
# Name: TrainingTimesLastYear, Length: 1470, dtype: int64

# %% [markdown]
# # Hipótesis 1: Los empleados que menos cobran tienen más probabilidades de dejar la empresa.

# %%
age=pd.DataFrame(df.groupby("Age")[["MonthlyIncome","DistanceFromHome","DailyRate","MonthlyRate"]].mean())
age.head()
# Out:
#      MonthlyIncome  DistanceFromHome   DailyRate   MonthlyRate
# Age
# 18    22428.750000          6.125000  747.625000  14476.000000
# 19    16453.333333         10.555556  548.444444  15119.666667
# 20    24583.636364          7.090909  819.454545  16480.909091
# 21    22885.384615          9.076923  762.846154  17268.923077
# 22    24208.125000          8.437500  806.937500  14424.125000

# %%
age["Count"]=df.Age.value_counts(dropna=False) # adding new column to age
age.reset_index(level=0, inplace=True)
age.head()
# Out:
#    Age  MonthlyIncome  DistanceFromHome   DailyRate   MonthlyRate  Count
# 0   18   22428.750000          6.125000  747.625000  14476.000000      8
# 1   19   16453.333333         10.555556  548.444444  15119.666667      9
# 2   20   24583.636364          7.090909  819.454545  16480.909091     11
# 3   21   22885.384615          9.076923  762.846154  17268.923077     13
# 4   22   24208.125000          8.437500  806.937500  14424.125000     16

# %%
plt.figure(figsize=(15,10))
ax=sns.barplot(x=age.Age,y=age.Count)
plt.xlabel("Age")
plt.ylabel("Counts")
plt.title("Age Counts")
plt.show()

# %%
sns.displot(data=df, x='MonthlyIncome', hue='Attrition', kind='kde', common_norm=False)

# %%
attrition_MonthlyRate = df_attrition.groupby('Attrition')['MonthlyIncome'].mean()
attrition_MonthlyRate
# Out:
# Attrition
# 0    24375.133820
# 1    22510.886076
# Name: MonthlyIncome, dtype: float64

# %%
left = df_attrition[df_attrition['Attrition']==1]['MonthlyIncome']
remain = df_attrition[df_attrition['Attrition']==0]['MonthlyIncome']

media_left = np.mean(left)
std_left = np.std(left)

media_remain = np.mean(remain)
std_remain = np.std(remain)

from scipy.stats import ttest_ind

t, p = ttest_ind(left, remain, equal_var=True)

print("Valor t:", t)
print("Valor p:", p)
# Out:
# Valor t: -2.1740836777017747
# Valor p: 0.02985816066026497

# %%
# una diferencia significativa
# en los salarios entre los empleados que se han ido de la empresa y los que se han quedado.

# %% [markdown]
# # Hipótesis 2: Los empleados que viven más lejos tienen más probabilidades de dejar la empresa que los empleados viven cerca.

# %%
columna = df["DistanceFromHome"]

DistanceFromHome_unicos = columna.unique()
print(DistanceFromHome_unicos)
# Out:
# [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]

# %%
columna2 = df["OverTime"]

Overtime_unicos = columna2.unique()
print(Overtime_unicos)
# Out:
# ['Yes' 'No']

# %%
corr_Distance_Attrition = df['DistanceFromHome'].corr(df['Attrition'])
corr_Distance_Attrition
# Out:
# 0.07792358295570372

# %%
plt.subplots(figsize=(18,5))
sns.countplot(df.DistanceFromHome)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='count'>

# %%
sns.boxplot(x='Attrition', y='DistanceFromHome', data=df)
plt.show()

# %%
sns.histplot(data=df, x='DistanceFromHome', hue='Attrition', multiple='stack', kde=False)
plt.show()

# %%
#T-Student
group_0 = df[df['Attrition'] == 0]['DistanceFromHome']
group_1 = df[df['Attrition'] == 1]['DistanceFromHome']

t_statistic, p_value = ttest_ind(group_0, group_1)

print("t-Statistic: ", t_statistic)
print("p-value: ", p_value)
# Out:
# t-Statistic:  -2.994708098265125
# p-value:  0.0027930600802134266

# %%
grouped_data = df.groupby('Attrition')['Age'].describe()
print(grouped_data)
# Out:
#             count       mean      std   min   25%   50%   75%   max
# Attrition
# 0          1233.0  37.561233  8.88836  18.0  31.0  36.0  43.0  60.0
# 1           237.0  33.607595  9.68935  18.0  28.0  32.0  39.0  58.0

# %%
df_attrition_1 = df.loc[df['Attrition'] == 1]

df_attrition_0 = df.loc[df['Attrition'] == 0]

# %%
df_combined = pd.concat([df_attrition_0, df_attrition_1])

sns.barplot(x='Attrition', y='Age', data=df)

plt.title('Left vs Remain')
plt.xlabel('Attrition')
plt.ylabel('Age')

plt.show()

# %%
group_1 = df[df['Attrition'] == 1]['Age']
group_2 = df[df['Attrition'] == 0]['Age']

# %%
t, p = stats.ttest_ind(group_1, group_2)
print("Valor t:", t)
print("Valor p:", p)
# Out:
# Valor t: -6.178663835307217
# Valor p: 8.356308021103587e-10

# %%
if p < 0.05:
    print('La diferencia en la edad es estadísticamente significativa.')
else:
    print('La diferencia en la edad no es estadísticamente significativa.')
# Out:
# La diferencia en la edad es estadísticamente significativa.

# %%
GENDER VS YEARS IN THE COMPANY

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('sqlite:///df.db')

df = pd.read_sql_query('SELECT * FROM employee', engine)

resultado = df.query('age > 30 and attrition == "Yes"')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818                 if not evt_handled:
# -> 1819                     self.dialect.do_execute(
#    1820                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# OperationalError: no such table: employee
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...
